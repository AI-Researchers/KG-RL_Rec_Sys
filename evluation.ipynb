# %%
import pickle
import pandas as pd
import boto3
import sagemaker
import io

# %%
region = boto3.Session().region_name
role = sagemaker.get_execution_role()

bucket='dlsg-training-data-prod'
prefix = 'a708148/' 
kms_key = "arn:aws:kms:us-east-1:647324198242:alias/ap131630-sagemaker"
sagemaker_session = sagemaker.Session()

s3_input      = 's3://'+bucket+'/'+prefix+'Rec_sys_challenge/original_dataset/'
s3_output_location  = 's3://'+bucket+'/'+prefix+'Rec_sys_challenge/output/'

# %%
import numpy as np

def apk(actual, predicted, k=10):
    """
    Computes the average precision at k.
    This function computes the average prescision at k between two lists of
    items.
    Parameters
    ----------
    actual : list
             A list of elements that are to be predicted (order doesn't matter)
    predicted : list
                A list of predicted elements (order does matter)
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The average precision at k over the input lists
    """
    if len(predicted)>k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i,p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i+1.0)

    if not actual:
        return 0.0

    return score / min(len(actual), k)

def mapk(actual, predicted, k=10):
    """
    Computes the mean average precision at k.
    This function computes the mean average prescision at k between two lists
    of lists of items.
    Parameters
    ----------
    actual : list
             A list of lists of elements that are to be predicted 
             (order doesn't matter in the lists)
    predicted : list
                A list of lists of predicted elements
                (order matters in the lists)
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The mean average precision at k over the input lists
    """
    return np.mean([apk(a,p,k) for a,p in zip(actual, predicted)])

# %%
def _ark(actual: list, predicted: list, k=10) -> int:
    """
    Computes the average recall at k.
    Parameters
    ----------
    actual : list
        A list of actual items to be predicted
    predicted : list
        An ordered list of predicted items
    k : int, default = 10
        Number of predictions to consider
    Returns:
    -------
    score : int
        The average recall at k.
    """
    if len(predicted)>k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i,p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i+1.0)

    if not actual:
        return 0.0

    return score / len(actual)

def mark(actual: [list], predicted: [list], k=10) -> int:
    """
    Computes the mean average recall at k.
    Parameters
    ----------
    actual : a list of lists
        Actual items to be predicted
        example: [['A', 'B', 'X'], ['A', 'B', 'Y']]
    predicted : a list of lists
        Ordered predictions
        example: [['X', 'Y', 'Z'], ['X', 'Y', 'Z']]
    Returns:
    -------
        mark: int
            The mean average recall at k (mar@k)
    """
    return np.mean([_ark(a,p,k) for a,p in zip(actual, predicted)])

# %%
def novelty(predicted: [list], pop: dict, u: int, n: int) -> (float, list):
    """
    Computes the novelty for a list of recommendations
    Parameters
    ----------
    predicted : a list of lists
        Ordered predictions
        example: [['X', 'Y', 'Z'], ['X', 'Y', 'Z']]
    pop: dictionary
        A dictionary of all items alongside of its occurrences counter in the training data
        example: {1198: 893, 1270: 876, 593: 876, 2762: 867}
    u: integer
        The number of users in the training data
    n: integer
        The length of recommended lists per user
    Returns
    ----------
    novelty:
        The novelty of the recommendations in system level
    mean_self_information:
        The novelty of the recommendations in recommended top-N list level
    ----------    
    Metric Defintion:
    Zhou, T., Kuscsik, Z., Liu, J. G., Medo, M., Wakeling, J. R., & Zhang, Y. C. (2010).
    Solving the apparent diversity-accuracy dilemma of recommender systems.
    Proceedings of the National Academy of Sciences, 107(10), 4511-4515.
    """
    mean_self_information = []
    k = 0
    for sublist in predicted:
        self_information = 0
        k += 1
        for i in sublist:
            if pop[i]!=0:
                self_information += np.sum(-np.log2(pop[i]/u))
        mean_self_information.append(self_information/n)
    novelty = sum(mean_self_information)/k
    #return novelty, mean_self_information
    return novelty

# %%
def prediction_coverage(predicted: [list], catalog: list) -> float:
    """
    Computes the prediction coverage for a list of recommendations
    Parameters
    ----------
    predicted : a list of lists
        Ordered predictions
        example: [['X', 'Y', 'Z'], ['X', 'Y', 'Z']]
    catalog: list
        A list of all unique items in the training data
        example: ['A', 'B', 'C', 'X', 'Y', Z]
    Returns
    ----------
    prediction_coverage:
        The prediction coverage of the recommendations as a percent
        rounded to 2 decimal places
    ----------    
    Metric Defintion:
    Ge, M., Delgado-Battenfeld, C., & Jannach, D. (2010, September).
    Beyond accuracy: evaluating recommender systems by coverage and serendipity.
    In Proceedings of the fourth ACM conference on Recommender systems (pp. 257-260). ACM.
    """
    predicted_flattened = [p for sublist in predicted for p in sublist]
    unique_predictions = len(set(predicted_flattened))
    prediction_coverage = round(unique_predictions/(len(catalog)* 1.0)*100,2)
    return prediction_coverage

# %%
def catalog_coverage(predicted: [list], catalog: list, k: int) -> float:
    """
    Computes the catalog coverage for k lists of recommendations
    Parameters
    ----------
    predicted : a list of lists
        Ordered predictions
        example: [['X', 'Y', 'Z'], ['X', 'Y', 'Z']]
    catalog: list
        A list of all unique items in the training data
        example: ['A', 'B', 'C', 'X', 'Y', Z]
    k: integer
        The number of observed recommendation lists
        which randomly choosed in our offline setup
    Returns
    ----------
    catalog_coverage:
        The catalog coverage of the recommendations as a percent
        rounded to 2 decimal places
    ----------    
    Metric Defintion:
    Ge, M., Delgado-Battenfeld, C., & Jannach, D. (2010, September).
    Beyond accuracy: evaluating recommender systems by coverage and serendipity.
    In Proceedings of the fourth ACM conference on Recommender systems (pp. 257-260). ACM.
    """
    sampling = random.choices(predicted, k=k)
    predicted_flattened = [p for sublist in sampling for p in sublist]
    L_predictions = len(set(predicted_flattened))
    catalog_coverage = round(L_predictions/(len(catalog)*1.0)*100,2)
    return catalog_coverage

# %%
real_list = pickle.load(open('./tmp/Challenge_Dataset/real_list.dat', 'rb'))
pred_list = pickle.load(open('./tmp/Challenge_Dataset/pred_list.dat', 'rb'))

# %%
mapk(real_list,pred_list,10)
# Out:
# 0.19533033177380418

# %%
mark(real_list,pred_list,10)
# Out:
# 0.19533033177380418

# %%
articles = sagemaker.s3.S3Downloader.read_file('s3://dlsg-training-data-prod/a708148/Rec_sys_challenge/original_dataset/articles.csv', sagemaker_session)
articles = pd.read_csv(io.StringIO(articles), sep=",")

# %%
df = sagemaker.s3.S3Downloader.read_file('s3://dlsg-training-data-prod/a708148/Rec_sys_challenge/original_dataset/Rec_Sys_sample_train_data_v3.csv', sagemaker_session)
df = pd.read_csv(io.StringIO(df), sep=",")

# %%
article_id=articles['tcm_id'].unique()

# %%
def index_set(s):
    i = 0
    s_map = {}
    for key in s:
        s_map[key] = str(i)
        i+=1
    return s_map

# %%
article_map = index_set(article_id)

# %%
len(article_map.keys())
# Out:
# 71

# %%
#pred_list
idx = [] 
for tcm_id in df['tcm_id']:
    idx.append(int(article_map[tcm_id]))
df['article_idx']= idx

# %%
ids = df.article_idx.value_counts()
print(len(ids))
pop = dict(ids)
for i in range(71):
    if i not in pop.keys():
        pop[i]=0
# Out:
# 66

# %%
novelty(pred_list,pop,len(article_id),10)
# Out:
# -3.5692534240278673

# %%
#catalog = articles.tcm_id.unique().tolist()
catalog = df['article_idx'].unique().tolist()

# %%
prediction_coverage(pred_list, catalog)
# Out:
# 93.94

# %%
import random
catalog_coverage(pred_list, catalog, 10)
# Out:
# 69.7

# %% [markdown]
# ### convert user, article index to real user, article id

# %%
import pickle
best_pred_path = pickle.load(open('./tmp/Challenge_Dataset/best_pred_path.dat', 'rb'))

# %%
def index_set(s):
    i = 0
    s_map = {}
    for key in s:
        s_map[key] = str(i)
        i+=1
    return s_map

# %%
user_id = df['ip'].unique()
article_id=articles['tcm_id'].unique()
topic_list = []
topics = articles['topic'].dropna()
for topic in topics:
    t = topic.strip('[').strip(']').strip().split(',')
    for i in range(len(t)):
        j = t[i].strip().replace("'",'')
        if j not in topic_list:
            topic_list.append(j)
topic_tag_list = []
topic_tags = articles['vstopic'].dropna()
for tag in topic_tags:
    t = tag.strip('[').strip(']').strip().split(',')
    for i in range(len(t)):
        j = t[i].strip().replace("'",'')
        if j not in topic_tag_list:
            topic_tag_list.append(j)
product_list = []
products = articles['product'].dropna()
for product in products:
    t = product.strip('[').strip(']').strip().split(',')
    for i in range(len(t)):
        j = t[i].strip().replace("'",'')
        if j not in product_list:
            product_list.append(j)

# %%
user_map = index_set(user_id)
article_map = index_set(article_id)
topic_map = index_set(topic_list)
tag_map = index_set(topic_tag_list)
product_map = index_set(product_list)

# %%
user_map_trans = {v: k for k,v in user_map.items()}
article_map_trans = {v: k for k,v in article_map.items()}
product_map_trans = {v: k for k,v in product_map.items()}
topic_map_trans = {v: k for k,v in topic_map.items()}
tag_map_trans = {v: k for k,v in tag_map.items()}

# %%
best_pred_path_trans={}
for k,v in best_pred_path.items():
    k_d = k
    for i in v:
        j = i[len(i)-1]
        t = 0
        for k in j:
            if k[1]=='user':
                k = list(k)
                k[2]=user_map_trans[str(k[2])]
                k = tuple(k)
                #print(user_map_trans[str(k[2])])
            if k[1]=='article':
                k = list(k)
                k[2]=article_map_trans[str(k[2])]
                k = tuple(k)
            if k[1]=='product':
                k = list(k)
                k[2]=product_map_trans[str(k[2])]
            if k[1]=='topic':
                k = list(k)
                k[2]=topic_map_trans[str(k[2])]
            if k[1]=='tag':
                k = list(k)
                k[2]=tag_map_trans[str(k[2])]
            j[t]=k
            t+=1
        i = list(i)
        i[2]=j
        i = tuple(i)
    best_pred_path_trans[user_map_trans[str(k_d)]]=v

# %%
best_pred_path_trans
# Out:
# {246032369: [(2.418602,
#    1.0659369,
#    [('self_loop', 'user', 246032369),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 6399186),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (2.2512653,
#    1.0675228,
#    [('self_loop', 'user', 246032369),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 51124733),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (-3.7383742,
#    1.0651792,
#    [('self_loop', 'user', 246032369),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('recommended', 'user', 234000057),
#     ('recommended', 'article', 'tcm:526-199040')]),
#   (-1.0162165,
#    1.0674281,
#    [('self_loop', 'user', 246032369),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 331811),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (0.4814355,
#    1.0603366,
#    [('self_loop', 'user', 246032369),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 67789797),
#     ('recommended', 'article', 'tcm:526-388698')]),
#   (0.38164422,
#    1.0672266,
#    [('self_loop', 'user', 246032369),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 995047521),
#     ('recommended', 'article', 'tcm:526-249037')]),
#   (-1.5516917,
#    1.0631298,
#    [('self_loop', 'user', 246032369),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 224316520),
#     ('recommended', 'article', 'tcm:526-40469')]),
#   (-0.029331673,
#    1.0617613,
#    [('self_loop', 'user', 246032369),
#     ('recommended', 'article', 'tcm:526-10787'),
#     ('recommended', 'user', 224121305),
#     ('recommended', 'article', 'tcm:526-248966')]),
#   (3.5727017,
#    1.0504557,
#    [('self_loop', 'user', 246032369),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('also_response', 'related_article', 48),
#     ('also_response', 'article', 'tcm:526-679101')]),
#   (-1.402822,
#    1.0665884,
#    [('self_loop', 'user', 246032369),
#     ('recommended', 'article', 'tcm:526-93195'),
#     ('recommended', 'user', 224588091),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (0.9068541,
#    1.0643212,
#    [('self_loop', 'user', 246032369),
#     ('recommended', 'article', 'tcm:526-418532'),
#     ('recommended', 'user', 224605698),
#     ('recommended', 'article', 'tcm:526-704480')]),
#   (-0.793211,
#    1.06071,
#    [('self_loop', 'user', 246032369),
#     ('recommended', 'article', 'tcm:526-93195'),
#     ('recommended', 'user', 17484344),
#     ('recommended', 'article', 'tcm:526-191289')])],
#  246877993: [(3.4376774,
#    1.0788195,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-258965'),
#     ('recommended', 'user', 25351822),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (-1.4594295,
#    1.0730611,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 46709868),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (-2.3777127,
#    1.08064,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-258965'),
#     ('recommended', 'user', 224367179),
#     ('recommended', 'article', 'tcm:526-209028')]),
#   (-3.908565,
#    1.071349,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-258965'),
#     ('recommended', 'user', 25149442),
#     ('recommended', 'article', 'tcm:526-46242')]),
#   (0.039108872,
#    1.07543,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-93195'),
#     ('recommended', 'user', 253791749),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (-1.0862701,
#    1.0785433,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('recommended', 'user', 53085915),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (3.3707576,
#    1.0656832,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('also_response', 'related_article', 53),
#     ('also_response', 'article', 'tcm:526-784445')]),
#   (0.048545964,
#    1.075401,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 27115991),
#     ('recommended', 'article', 'tcm:526-249037')]),
#   (-0.5014467,
#    1.0712129,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-276414'),
#     ('recommended', 'user', 83047),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (-5.324122,
#    1.0728819,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 8394959),
#     ('recommended', 'article', 'tcm:526-655038')]),
#   (-0.7616121,
#    1.0762914,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('recommended', 'user', 228831671),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (2.4084275,
#    1.0791607,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-40469'),
#     ('recommended', 'user', 57331836),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (-5.3038087,
#    1.0746101,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-259315'),
#     ('recommended', 'user', 3693775),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (-2.665587,
#    1.0569016,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('also_response', 'related_article', 35),
#     ('response_together', 'article', 'tcm:526-273898')]),
#   (-0.16827245,
#    1.0700315,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 231129506),
#     ('recommended', 'article', 'tcm:526-261006')]),
#   (-0.0012274454,
#    1.0567093,
#    [('self_loop', 'user', 246877993),
#     ('recommended', 'article', 'tcm:526-688510'),
#     ('also_response', 'related_article', 69),
#     ('also_response', 'article', 'tcm:526-385364')])],
#  256812581: [(-2.2330825,
#    1.0663053,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 17474317),
#     ('recommended', 'article', 'tcm:526-187302')]),
#   (-2.1284552,
#    1.0634751,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 19824731),
#     ('recommended', 'article', 'tcm:526-346380')]),
#   (-0.18661699,
#    1.0661857,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 223603595),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (-0.5754238,
#    1.0632856,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-707567'),
#     ('recommended', 'user', 205962398),
#     ('recommended', 'article', 'tcm:526-191289')]),
#   (-2.2587214,
#    1.061415,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('recommended', 'user', 440748),
#     ('recommended', 'article', 'tcm:526-209028')]),
#   (1.3002374,
#    1.0602005,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 30510366),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (0.012006068,
#    1.0631374,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-224772'),
#     ('recommended', 'user', 50199017),
#     ('recommended', 'article', 'tcm:526-385364')]),
#   (-1.0527917,
#    1.0549442,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 60213291),
#     ('recommended', 'article', 'tcm:526-258965')]),
#   (0.47615644,
#    1.064239,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('recommended', 'user', 19473289),
#     ('recommended', 'article', 'tcm:526-388698')]),
#   (3.5409575,
#    1.0614564,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-248966'),
#     ('recommended', 'user', 64805158),
#     ('recommended', 'article', 'tcm:526-784445')]),
#   (1.0143688,
#    1.0644019,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-259315'),
#     ('recommended', 'user', 51246675),
#     ('recommended', 'article', 'tcm:526-712788')]),
#   (3.7190948,
#    1.0642223,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 3454504),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (-0.76961297,
#    1.0493543,
#    [('self_loop', 'user', 256812581),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('also_response', 'related_article', 35),
#     ('also_response', 'article', 'tcm:526-237984')])],
#  992394584: [(0.027908599,
#    1.0542262,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('also_response', 'related_article', 10),
#     ('also_response', 'article', 'tcm:526-385364')]),
#   (0.17331038,
#    1.0705894,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-273898'),
#     ('recommended', 'user', 229203735),
#     ('recommended', 'article', 'tcm:526-12167')]),
#   (1.3178492,
#    1.0655636,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-782343'),
#     ('recommended', 'user', 24123238),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (-4.153017,
#    1.0678557,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 379682),
#     ('recommended', 'article', 'tcm:526-164352')]),
#   (2.5032473,
#    1.064309,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 3756936),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (-3.903721,
#    1.0714941,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 395075),
#     ('recommended', 'article', 'tcm:526-199040')]),
#   (-1.0222312,
#    1.0718259,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('recommended', 'user', 395075),
#     ('recommended', 'article', 'tcm:526-259315')]),
#   (0.84970057,
#    1.0698105,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-249037'),
#     ('recommended', 'user', 3319061),
#     ('recommended', 'article', 'tcm:526-704480')]),
#   (-1.9174345,
#    1.0663779,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 3665466),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (3.5658376,
#    1.0596223,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 32216753),
#     ('recommended', 'article', 'tcm:526-52560')]),
#   (-1.154627,
#    1.0511833,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('also_response', 'related_article', 40),
#     ('also_response', 'article', 'tcm:526-258965')]),
#   (-4.059179,
#    1.0621256,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-191289'),
#     ('recommended', 'user', 24995806),
#     ('recommended', 'article', 'tcm:526-551763')]),
#   (2.65465,
#    1.0628009,
#    [('self_loop', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 19825373),
#     ('recommended', 'article', 'tcm:526-224772')])],
#  995802261: [(-2.955586,
#    1.0557576,
#    [('self_loop', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-248966'),
#     ('also_response', 'related_article', 29),
#     ('also_response', 'article', 'tcm:526-249921')]),
#   (-1.9911754,
#    1.066736,
#    [('self_loop', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-248966'),
#     ('recommended', 'user', 225104205),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (-0.68213266,
#    1.062736,
#    [('self_loop', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 40830434),
#     ('recommended', 'article', 'tcm:526-191289')]),
#   (-0.6321647,
#    1.0677497,
#    [('self_loop', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 25980052),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (-0.03133112,
#    1.0659624,
#    [('self_loop', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-52560'),
#     ('recommended', 'user', 32233690),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (2.6310802,
#    1.0689218,
#    [('self_loop', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (-1.9543711,
#    1.0654788,
#    [('self_loop', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-209028'),
#     ('recommended', 'user', 8389961),
#     ('recommended', 'article', 'tcm:526-187302')]),
#   (0.8577571,
#    1.0736718,
#    [('self_loop', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-10849'),
#     ('recommended', 'user', 395075),
#     ('recommended', 'article', 'tcm:526-704480')]),
#   (-3.0887198,
#    1.0724145,
#    [('self_loop', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 27434531),
#     ('recommended', 'article', 'tcm:526-695181')]),
#   (1.3599732,
#    1.0744094,
#    [('self_loop', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 395075),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (-1.0833468,
#    1.0519449,
#    [('self_loop', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-249037'),
#     ('also_response', 'related_article', 7),
#     ('also_response', 'article', 'tcm:526-259315')]),
#   (-0.9389996,
#    1.0646375,
#    [('self_loop', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 848272),
#     ('recommended', 'article', 'tcm:526-239640')])],
#  244634854: [(1.334187,
#    1.0704421,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 395075),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (-0.8437216,
#    1.0647446,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-187302'),
#     ('recommended', 'user', 1502294),
#     ('recommended', 'article', 'tcm:526-191289')]),
#   (1.7717689,
#    1.0618787,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-688510'),
#     ('recommended', 'user', 10340103),
#     ('recommended', 'article', 'tcm:526-670542')]),
#   (-2.7827284,
#    1.0648018,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-10849'),
#     ('recommended', 'user', 5490499),
#     ('recommended', 'article', 'tcm:526-13782')]),
#   (-4.1949763,
#    1.0680993,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('recommended', 'user', 58740585),
#     ('recommended', 'article', 'tcm:526-164352')]),
#   (2.9458601,
#    1.0489049,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-418532'),
#     ('also_response', 'related_article', 57),
#     ('also_response', 'article', 'tcm:526-153236')]),
#   (1.2721435,
#    1.0496802,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-249037'),
#     ('also_response', 'related_article', 7),
#     ('recommended_together', 'article', 'tcm:526-12180')]),
#   (2.845189,
#    1.0626734,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 3463972),
#     ('recommended', 'article', 'tcm:526-681575')]),
#   (2.1711893,
#    1.0609154,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-688510'),
#     ('recommended', 'user', 57000249),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (-2.7043636,
#    1.0497018,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-688510'),
#     ('also_response', 'related_article', 7),
#     ('also_response', 'article', 'tcm:526-674187')]),
#   (-1.2651935,
#    1.0494125,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('also_response', 'related_article', 58),
#     ('also_response', 'article', 'tcm:526-682379')]),
#   (0.22780283,
#    1.0597541,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-10849'),
#     ('recommended', 'user', 224532617),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (1.3448787,
#    1.0486753,
#    [('self_loop', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-707527'),
#     ('also_response', 'related_article', 36),
#     ('also_response', 'article', 'tcm:526-276414')])],
#  254787070: [(0.8963542,
#    1.0663036,
#    [('self_loop', 'user', 254787070),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('recommended', 'user', 142942),
#     ('recommended', 'article', 'tcm:526-704480')]),
#   (-5.188465,
#    1.0686241,
#    [('self_loop', 'user', 254787070),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 63772432),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (4.119251,
#    1.0511445,
#    [('self_loop', 'user', 254787070),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('also_response', 'related_article', 14),
#     ('also_response', 'article', 'tcm:526-707567')]),
#   (-2.4318151,
#    1.0588509,
#    [('self_loop', 'user', 254787070),
#     ('recommended', 'article', 'tcm:526-209028'),
#     ('recommended', 'user', 40830434),
#     ('recommended', 'article', 'tcm:526-10849')]),
#   (8.518361,
#    1.0654993,
#    [('self_loop', 'user', 254787070),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('recommended', 'user', 17967010),
#     ('recommended', 'article', 'tcm:526-707527')]),
#   (-4.110392,
#    1.0601088,
#    [('self_loop', 'user', 254787070),
#     ('recommended', 'article', 'tcm:526-261006'),
#     ('recommended', 'user', 781367),
#     ('recommended', 'article', 'tcm:526-551763')])],
#  994288018: [(-0.8729785,
#    1.06511,
#    [('self_loop', 'user', 994288018),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('recommended', 'user', 22409500),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (2.4496508,
#    1.0590051,
#    [('self_loop', 'user', 994288018),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 6923285),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (-0.58797425,
#    1.0622976,
#    [('self_loop', 'user', 994288018),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (0.012706572,
#    1.0630295,
#    [('self_loop', 'user', 994288018),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 722143),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (-1.279708,
#    1.057437,
#    [('self_loop', 'user', 994288018),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 6923285),
#     ('recommended', 'article', 'tcm:526-40469')]),
#   (1.8750815,
#    1.0497371,
#    [('self_loop', 'user', 994288018),
#     ('recommended', 'article', 'tcm:526-707527'),
#     ('also_response', 'related_article', 30),
#     ('also_response', 'article', 'tcm:526-670542')]),
#   (4.0597296,
#    1.0627162,
#    [('self_loop', 'user', 994288018),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('recommended', 'user', 27429732),
#     ('recommended', 'article', 'tcm:526-707567')]),
#   (3.1390002,
#    1.061455,
#    [('self_loop', 'user', 994288018),
#     ('recommended', 'article', 'tcm:526-273898'),
#     ('recommended', 'user', 27981123),
#     ('recommended', 'article', 'tcm:526-681575')]),
#   (-2.7196891,
#    1.0629721,
#    [('self_loop', 'user', 994288018),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 31563932),
#     ('recommended', 'article', 'tcm:526-674187')]),
#   (1.3871696,
#    1.056829,
#    [('self_loop', 'user', 994288018),
#     ('recommended', 'article', 'tcm:526-10787'),
#     ('recommended', 'user', 224704393),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (0.96709853,
#    1.0661342,
#    [('self_loop', 'user', 994288018),
#     ('recommended', 'article', 'tcm:526-385364'),
#     ('recommended', 'user', 27115991),
#     ('recommended', 'article', 'tcm:526-712788')])],
#  224390418: [(-2.5956311,
#    1.067519,
#    [('self_loop', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 441296),
#     ('recommended', 'article', 'tcm:526-273898')]),
#   (1.1627296,
#    1.0653044,
#    [('self_loop', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 24164519),
#     ('recommended', 'article', 'tcm:526-712788')]),
#   (-1.5170207,
#    1.0667815,
#    [('self_loop', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 38031580),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (-0.71123916,
#    1.0687832,
#    [('self_loop', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-782343'),
#     ('recommended', 'user', 224427606),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (-5.4888196,
#    1.0648218,
#    [('self_loop', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-654768'),
#     ('recommended', 'user', 1965937),
#     ('recommended', 'article', 'tcm:526-655038')]),
#   (-2.6139753,
#    1.0623481,
#    [('self_loop', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-52560'),
#     ('recommended', 'user', 992282589),
#     ('recommended', 'article', 'tcm:526-209028')]),
#   (-1.8720812,
#    1.065416,
#    [('self_loop', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-782343'),
#     ('recommended', 'user', 46747611),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (1.2342455,
#    1.0730015,
#    [('self_loop', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 39914546),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (-0.09297545,
#    1.0511931,
#    [('self_loop', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-782343'),
#     ('also_response', 'related_article', 42),
#     ('also_response', 'article', 'tcm:526-656536')]),
#   (0.43871722,
#    1.0498573,
#    [('self_loop', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-704480'),
#     ('also_response', 'related_article', 38),
#     ('also_response', 'article', 'tcm:526-248966')]),
#   (-1.0147865,
#    1.0655767,
#    [('self_loop', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-70899'),
#     ('recommended', 'user', 1655379),
#     ('recommended', 'article', 'tcm:526-259315')]),
#   (0.032337826,
#    1.0503837,
#    [('self_loop', 'user', 224390418),
#     ('recommended', 'article', 'tcm:526-418532'),
#     ('also_response', 'related_article', 32),
#     ('also_response', 'article', 'tcm:526-385364')])],
#  224772209: [(0.42461658,
#    1.0714012,
#    [('self_loop', 'user', 224772209),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 6923306),
#     ('recommended', 'article', 'tcm:526-248966')]),
#   (16.436445,
#    1.0585531,
#    [('self_loop', 'user', 224772209),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 18496482),
#     ('recommended', 'article', 'tcm:526-10787')]),
#   (1.1108485,
#    1.0580714,
#    [('self_loop', 'user', 224772209),
#     ('recommended', 'article', 'tcm:526-191289'),
#     ('recommended', 'user', 35368310),
#     ('recommended', 'article', 'tcm:526-712788')]),
#   (-0.95105946,
#    1.065442,
#    [('self_loop', 'user', 224772209),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 224932470),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (-0.7732531,
#    1.060583,
#    [('self_loop', 'user', 224772209),
#     ('recommended', 'article', 'tcm:526-654768'),
#     ('recommended', 'user', 642335),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (-5.449352,
#    1.0650244,
#    [('self_loop', 'user', 224772209),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 27643245),
#     ('recommended', 'article', 'tcm:526-655038')]),
#   (8.3647,
#    1.064728,
#    [('self_loop', 'user', 224772209),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('recommended', 'user', 20266788),
#     ('recommended', 'article', 'tcm:526-707527')]),
#   (-0.01265524,
#    1.0581857,
#    [('self_loop', 'user', 224772209),
#     ('recommended', 'article', 'tcm:526-684643'),
#     ('recommended', 'user', 56925601),
#     ('recommended', 'article', 'tcm:526-385364')])],
#  224778881: [(4.0497565,
#    1.0689471,
#    [('self_loop', 'user', 224778881),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('recommended', 'user', 867232),
#     ('recommended', 'article', 'tcm:526-707567')]),
#   (-0.8517572,
#    1.0626873,
#    [('self_loop', 'user', 224778881),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('recommended', 'user', 47811),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (-0.6392763,
#    1.0669985,
#    [('self_loop', 'user', 224778881),
#     ('recommended', 'article', 'tcm:526-782343'),
#     ('recommended', 'user', 23584598),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (-1.1570592,
#    1.0495417,
#    [('self_loop', 'user', 224778881),
#     ('recommended', 'article', 'tcm:526-682576'),
#     ('also_response', 'related_article', 1),
#     ('also_response', 'article', 'tcm:526-258965')]),
#   (0.06209035,
#    1.063283,
#    [('self_loop', 'user', 224778881),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 57000249),
#     ('recommended', 'article', 'tcm:526-249037')]),
#   (-1.8921188,
#    1.065716,
#    [('self_loop', 'user', 224778881),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 206875883),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (-2.6327608,
#    1.0628426,
#    [('self_loop', 'user', 224778881),
#     ('recommended', 'article', 'tcm:526-40469'),
#     ('recommended', 'user', 7898938),
#     ('recommended', 'article', 'tcm:526-209028')]),
#   (-5.017152,
#    1.0619093,
#    [('self_loop', 'user', 224778881),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 578717),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (-0.8151806,
#    1.06109,
#    [('self_loop', 'user', 224778881),
#     ('recommended', 'article', 'tcm:526-704480'),
#     ('recommended', 'user', 503477),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (8.454557,
#    1.0608349,
#    [('self_loop', 'user', 224778881),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('recommended', 'user', 50595618),
#     ('recommended', 'article', 'tcm:526-707527')]),
#   (-0.98900807,
#    1.0498589,
#    [('self_loop', 'user', 224778881),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('also_response', 'related_article', 33),
#     ('response_together', 'article', 'tcm:526-259315')])],
#  224955660: [(-2.7408364,
#    1.0679283,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-10787'),
#     ('recommended', 'user', 26913983),
#     ('recommended', 'article', 'tcm:526-13782')]),
#   (-0.99282324,
#    1.0704144,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 24272477),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (2.458857,
#    1.0647955,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-684643'),
#     ('recommended', 'user', 13256378),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (1.4073536,
#    1.0755812,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('recommended', 'user', 17963247),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (-3.7564662,
#    1.0646751,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 244634854),
#     ('recommended', 'article', 'tcm:526-199040')]),
#   (1.8995779,
#    1.0667868,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 224372265),
#     ('recommended', 'article', 'tcm:526-670542')]),
#   (-1.4610826,
#    1.05435,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('also_response', 'related_article', 30),
#     ('also_response', 'article', 'tcm:526-40469')]),
#   (3.630388,
#    1.065942,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 25440846),
#     ('recommended', 'article', 'tcm:526-52560')]),
#   (0.90551883,
#    1.0523517,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-782343'),
#     ('also_response', 'related_article', 4),
#     ('also_response', 'article', 'tcm:526-704480')]),
#   (0.8164891,
#    1.0679657,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-191289'),
#     ('recommended', 'user', 29057094),
#     ('recommended', 'article', 'tcm:526-418532')]),
#   (3.136647,
#    1.0665677,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 3915552),
#     ('recommended', 'article', 'tcm:526-681575')]),
#   (-2.7419627,
#    1.0646609,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 62049039),
#     ('recommended', 'article', 'tcm:526-674187')]),
#   (0.104770795,
#    1.0662283,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 232720594),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (1.3992198,
#    1.0524596,
#    [('self_loop', 'user', 224955660),
#     ('recommended', 'article', 'tcm:526-224772'),
#     ('also_response', 'related_article', 7),
#     ('response_together', 'article', 'tcm:526-12180')])],
#  234117294: [(3.4686015,
#    1.0674957,
#    [('self_loop', 'user', 234117294),
#     ('recommended', 'article', 'tcm:526-46242'),
#     ('recommended', 'user', 57331836),
#     ('recommended', 'article', 'tcm:526-52560')]),
#   (-4.0111475,
#    1.06507,
#    [('self_loop', 'user', 234117294),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 225367366),
#     ('recommended', 'article', 'tcm:526-551763')]),
#   (-2.0916424,
#    1.0614389,
#    [('self_loop', 'user', 234117294),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('recommended', 'user', 28315377),
#     ('recommended', 'article', 'tcm:526-187302')]),
#   (0.78441346,
#    1.0605083,
#    [('self_loop', 'user', 234117294),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('recommended', 'user', 54614880),
#     ('recommended', 'article', 'tcm:526-418532')]),
#   (2.5130446,
#    1.0661489,
#    [('self_loop', 'user', 234117294),
#     ('recommended', 'article', 'tcm:526-707527'),
#     ('recommended', 'user', 57331836),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (1.5938298,
#    1.0509099,
#    [('self_loop', 'user', 234117294),
#     ('recommended', 'article', 'tcm:526-674187'),
#     ('also_response', 'related_article', 44),
#     ('also_response', 'article', 'tcm:526-276414')]),
#   (-2.3365684,
#    1.0613891,
#    [('self_loop', 'user', 234117294),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 17474317),
#     ('recommended', 'article', 'tcm:526-10849')]),
#   (-0.50502545,
#    1.0573903,
#    [('self_loop', 'user', 234117294),
#     ('recommended', 'article', 'tcm:526-261006'),
#     ('recommended', 'user', 57463874),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (-2.3000126,
#    1.0569701,
#    [('self_loop', 'user', 234117294),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 8634543),
#     ('recommended', 'article', 'tcm:526-346380')])],
#  235633343: [(-2.6182215,
#    1.065928,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 352170),
#     ('recommended', 'article', 'tcm:526-674187')]),
#   (0.9187033,
#    1.0652609,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-209028'),
#     ('recommended', 'user', 205962398),
#     ('recommended', 'article', 'tcm:526-704480')]),
#   (-0.112807,
#    1.0497046,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-551763'),
#     ('also_response', 'related_article', 65),
#     ('also_response', 'article', 'tcm:526-261006')]),
#   (1.4042146,
#    1.0627081,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 200506324),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (2.4921026,
#    1.0489563,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-209028'),
#     ('also_response', 'related_article', 3),
#     ('also_response', 'article', 'tcm:526-654768')]),
#   (-0.14591946,
#    1.0622877,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-10849'),
#     ('recommended', 'user', 245642575),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (3.0968997,
#    1.0630047,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-688510'),
#     ('recommended', 'user', 224592684),
#     ('recommended', 'article', 'tcm:526-681575')]),
#   (-0.440363,
#    1.0599589,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('recommended', 'user', 16350379),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (-2.047324,
#    1.0649443,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-40469'),
#     ('recommended', 'user', 28412544),
#     ('recommended', 'article', 'tcm:526-187302')]),
#   (1.5329502,
#    1.0491477,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('also_response', 'related_article', 46),
#     ('also_response', 'article', 'tcm:526-12180')]),
#   (1.912436,
#    1.0605431,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-10849'),
#     ('recommended', 'user', 224538733),
#     ('recommended', 'article', 'tcm:526-670542')]),
#   (-1.4918929,
#    1.0495824,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-385364'),
#     ('also_response', 'related_article', 34),
#     ('also_response', 'article', 'tcm:526-682379')]),
#   (0.36533335,
#    1.0488176,
#    [('self_loop', 'user', 235633343),
#     ('recommended', 'article', 'tcm:526-385364'),
#     ('also_response', 'related_article', 29),
#     ('also_response', 'article', 'tcm:526-249037')])],
#  235847363: [(-4.024529,
#    1.0632706,
#    [('self_loop', 'user', 235847363),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 53529476),
#     ('recommended', 'article', 'tcm:526-164352')]),
#   (0.3017665,
#    1.0618384,
#    [('self_loop', 'user', 235847363),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 32438804),
#     ('recommended', 'article', 'tcm:526-388698')]),
#   (-1.3837572,
#    1.068022,
#    [('self_loop', 'user', 235847363),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 216454727),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (0.24441257,
#    1.0488505,
#    [('self_loop', 'user', 235847363),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('also_response', 'related_article', 40),
#     ('also_response', 'article', 'tcm:526-249037')]),
#   (-3.9735236,
#    1.0587904,
#    [('self_loop', 'user', 235847363),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 28642636),
#     ('recommended', 'article', 'tcm:526-551763')]),
#   (-5.192509,
#    1.0661043,
#    [('self_loop', 'user', 235847363),
#     ('recommended', 'article', 'tcm:526-204679'),
#     ('recommended', 'user', 30271660),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (8.623666,
#    1.0654124,
#    [('self_loop', 'user', 235847363),
#     ('recommended', 'article', 'tcm:526-418532'),
#     ('recommended', 'user', 225491746),
#     ('recommended', 'article', 'tcm:526-782343')]),
#   (2.4322476,
#    1.0605847,
#    [('self_loop', 'user', 235847363),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 224354619),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (-2.8235903,
#    1.047266,
#    [('self_loop', 'user', 235847363),
#     ('recommended', 'article', 'tcm:526-707567'),
#     ('also_response', 'related_article', 3),
#     ('also_response', 'article', 'tcm:526-249921')])],
#  48021813: [(-1.4525511,
#    1.0515583,
#    [('self_loop', 'user', 48021813),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('also_response', 'related_article', 34),
#     ('also_response', 'article', 'tcm:526-682379')]),
#   (8.607307,
#    1.0654608,
#    [('self_loop', 'user', 48021813),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('recommended', 'user', 31826251),
#     ('recommended', 'article', 'tcm:526-707527')]),
#   (-2.3032668,
#    1.0638123,
#    [('self_loop', 'user', 48021813),
#     ('recommended', 'article', 'tcm:526-46242'),
#     ('recommended', 'user', 7393693),
#     ('recommended', 'article', 'tcm:526-187302')]),
#   (-0.59121406,
#    1.06312,
#    [('self_loop', 'user', 48021813),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('recommended', 'user', 60747),
#     ('recommended', 'article', 'tcm:526-191289')]),
#   (1.3758856,
#    1.064141,
#    [('self_loop', 'user', 48021813),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 66834679),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (-0.8359174,
#    1.0607558,
#    [('self_loop', 'user', 48021813),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 30510366),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (0.0074745533,
#    1.0627775,
#    [('self_loop', 'user', 48021813),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 245642575),
#     ('recommended', 'article', 'tcm:526-385364')]),
#   (1.0564748,
#    1.0622214,
#    [('self_loop', 'user', 48021813),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('recommended', 'user', 6339036),
#     ('recommended', 'article', 'tcm:526-712788')]),
#   (0.054261424,
#    1.0477141,
#    [('self_loop', 'user', 48021813),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('also_response', 'related_article', 13),
#     ('also_response', 'article', 'tcm:526-248966')])],
#  50577399: [(-1.2013963,
#    1.070195,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-684643'),
#     ('recommended', 'user', 7332929),
#     ('recommended', 'article', 'tcm:526-258965')]),
#   (-0.6416539,
#    1.0736539,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 1917519),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (-3.8076482,
#    1.0707341,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('recommended', 'user', 53085915),
#     ('recommended', 'article', 'tcm:526-46242')]),
#   (-2.1352332,
#    1.0663297,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-385364'),
#     ('recommended', 'user', 2603949),
#     ('recommended', 'article', 'tcm:526-187302')]),
#   (-0.14695239,
#    1.0681282,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 51283633),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (1.6692739,
#    1.05314,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('also_response', 'related_article', 36),
#     ('response_together', 'article', 'tcm:526-276414')]),
#   (-1.0752633,
#    1.071111,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 17963247),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (-2.9712167,
#    1.0523202,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('also_response', 'related_article', 4),
#     ('also_response', 'article', 'tcm:526-249921')]),
#   (3.431883,
#    1.0607111,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('recommended', 'user', 992053226),
#     ('recommended', 'article', 'tcm:526-52560')]),
#   (-5.3898315,
#    1.0520529,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-674187'),
#     ('also_response', 'related_article', 8),
#     ('also_response', 'article', 'tcm:526-655038')]),
#   (3.5438833,
#    1.0688092,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-674187'),
#     ('recommended', 'user', 51124733),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (2.364264,
#    1.0653062,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 57907203),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (2.0620313,
#    1.0661879,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-80807'),
#     ('recommended', 'user', 51285380),
#     ('recommended', 'article', 'tcm:526-492865')]),
#   (-2.1912124,
#    1.0579523,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('also_response', 'related_article', 49),
#     ('also_response', 'article', 'tcm:526-346380')]),
#   (-3.9862597,
#    1.0772177,
#    [('self_loop', 'user', 50577399),
#     ('recommended', 'article', 'tcm:526-248966'),
#     ('recommended', 'user', 12500756),
#     ('recommended', 'article', 'tcm:526-551763')])],
#  59932972: [(3.6418822,
#    1.0677173,
#    [('self_loop', 'user', 59932972),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 224366054),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (-1.8051796,
#    1.0664656,
#    [('self_loop', 'user', 59932972),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 4971363),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (-5.5154877,
#    1.0654976,
#    [('self_loop', 'user', 59932972),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 3396847),
#     ('recommended', 'article', 'tcm:526-655038')]),
#   (-2.6991436,
#    1.0644869,
#    [('self_loop', 'user', 59932972),
#     ('recommended', 'article', 'tcm:526-418532'),
#     ('recommended', 'user', 22810361),
#     ('recommended', 'article', 'tcm:526-209028')]),
#   (1.2626369,
#    1.0772517,
#    [('self_loop', 'user', 59932972),
#     ('recommended', 'article', 'tcm:526-249037'),
#     ('recommended', 'user', 395075),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (-2.8929873,
#    1.0673141,
#    [('self_loop', 'user', 59932972),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 26829705),
#     ('recommended', 'article', 'tcm:526-674187')]),
#   (2.7618644,
#    1.06567,
#    [('self_loop', 'user', 59932972),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 27379636),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (-0.032276317,
#    1.0662212,
#    [('self_loop', 'user', 59932972),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('recommended', 'user', 19927744),
#     ('recommended', 'article', 'tcm:526-385364')]),
#   (-2.6355855,
#    1.0650269,
#    [('self_loop', 'user', 59932972),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 611053),
#     ('recommended', 'article', 'tcm:526-273898')]),
#   (1.4931519,
#    1.0521659,
#    [('self_loop', 'user', 59932972),
#     ('recommended', 'article', 'tcm:526-93195'),
#     ('also_response', 'related_article', 13),
#     ('also_response', 'article', 'tcm:526-276414')]),
#   (3.5976193,
#    1.0645871,
#    [('self_loop', 'user', 59932972),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 31039452),
#     ('recommended', 'article', 'tcm:526-784445')]),
#   (-0.6569877,
#    1.0680567,
#    [('self_loop', 'user', 59932972),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 1917519),
#     ('recommended', 'article', 'tcm:526-688510')])],
#  200248332: [(-2.4989784,
#    1.0644524,
#    [('self_loop', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 225052174),
#     ('recommended', 'article', 'tcm:526-209028')]),
#   (-0.10962257,
#    1.0627569,
#    [('self_loop', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-784445'),
#     ('recommended', 'user', 25904631),
#     ('recommended', 'article', 'tcm:526-385364')]),
#   (-5.2781963,
#    1.0670729,
#    [('self_loop', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 66007346),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (-2.7052648,
#    1.0530212,
#    [('self_loop', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('also_response', 'related_article', 44),
#     ('also_response', 'article', 'tcm:526-273898')]),
#   (2.5715628,
#    1.0669756,
#    [('self_loop', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-52560'),
#     ('recommended', 'user', 43993126),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (-0.95052606,
#    1.0657527,
#    [('self_loop', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-52560'),
#     ('recommended', 'user', 1890757),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (3.9686108,
#    1.0686505,
#    [('self_loop', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 224710627),
#     ('recommended', 'article', 'tcm:526-707567')]),
#   (8.323866,
#    1.0644686,
#    [('self_loop', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 38590499),
#     ('recommended', 'article', 'tcm:526-707527')]),
#   (0.98760974,
#    1.0628417,
#    [('self_loop', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-276414'),
#     ('recommended', 'user', 15103927),
#     ('recommended', 'article', 'tcm:526-712788')]),
#   (-0.63377047,
#    1.0644882,
#    [('self_loop', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('recommended', 'user', 142942),
#     ('recommended', 'article', 'tcm:526-191289')]),
#   (-0.6766696,
#    1.0627971,
#    [('self_loop', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('recommended', 'user', 19782136),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (-1.5006189,
#    1.0505674,
#    [('self_loop', 'user', 200248332),
#     ('recommended', 'article', 'tcm:526-654768'),
#     ('also_response', 'related_article', 56),
#     ('also_response', 'article', 'tcm:526-682379')])],
#  224156806: [(-4.0491953,
#    1.0686196,
#    [('self_loop', 'user', 224156806),
#     ('recommended', 'article', 'tcm:526-707527'),
#     ('recommended', 'user', 5267230),
#     ('recommended', 'article', 'tcm:526-551763')]),
#   (1.821187,
#    1.067961,
#    [('self_loop', 'user', 224156806),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('recommended', 'user', 39963168),
#     ('recommended', 'article', 'tcm:526-670542')]),
#   (3.458547,
#    1.0678691,
#    [('self_loop', 'user', 224156806),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 4167342),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (2.3549037,
#    1.0648195,
#    [('self_loop', 'user', 224156806),
#     ('recommended', 'article', 'tcm:526-688510'),
#     ('recommended', 'user', 13256378),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (0.87699425,
#    1.0721325,
#    [('self_loop', 'user', 224156806),
#     ('recommended', 'article', 'tcm:526-93195'),
#     ('recommended', 'user', 6911811),
#     ('recommended', 'article', 'tcm:526-704480')]),
#   (-4.001397,
#    1.0685793,
#    [('self_loop', 'user', 224156806),
#     ('recommended', 'article', 'tcm:526-209028'),
#     ('recommended', 'user', 51124733),
#     ('recommended', 'article', 'tcm:526-164352')]),
#   (-2.791886,
#    1.0538712,
#    [('self_loop', 'user', 224156806),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('also_response', 'related_article', 36),
#     ('also_response', 'article', 'tcm:526-249921')]),
#   (3.3547492,
#    1.0746906,
#    [('self_loop', 'user', 224156806),
#     ('recommended', 'article', 'tcm:526-249037'),
#     ('recommended', 'user', 27434531),
#     ('recommended', 'article', 'tcm:526-784445')]),
#   (3.1989307,
#    1.0642695,
#    [('self_loop', 'user', 224156806),
#     ('recommended', 'article', 'tcm:526-209028'),
#     ('recommended', 'user', 2587712),
#     ('recommended', 'article', 'tcm:526-52560')]),
#   (-2.2007513,
#    1.0707424,
# ...
#     ('also_response', 'related_article', 4),
#     ('also_response', 'article', 'tcm:526-249921')]),
#   (-0.5678037,
#    1.0645989,
#    [('self_loop', 'user', 27199581),
#     ('recommended', 'article', 'tcm:526-682576'),
#     ('recommended', 'user', 8042915),
#     ('recommended', 'article', 'tcm:526-191289')])],
#  27924569: [(-0.5568563,
#    1.0703428,
#    [('self_loop', 'user', 27924569),
#     ('recommended', 'article', 'tcm:526-46242'),
#     ('recommended', 'user', 5347989),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (-1.1204559,
#    1.0598806,
#    [('self_loop', 'user', 27924569),
#     ('recommended', 'article', 'tcm:526-418532'),
#     ('recommended', 'user', 24095001),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (0.458703,
#    1.0667267,
#    [('self_loop', 'user', 27924569),
#     ('recommended', 'article', 'tcm:526-199040'),
#     ('recommended', 'user', 24326158),
#     ('recommended', 'article', 'tcm:526-248966')]),
#   (-1.8244385,
#    1.0653703,
#    [('self_loop', 'user', 27924569),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 3479430),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (-1.217466,
#    1.0658016,
#    [('self_loop', 'user', 27924569),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 4748021),
#     ('recommended', 'article', 'tcm:526-258965')]),
#   (3.2726386,
#    1.0464336,
#    [('self_loop', 'user', 27924569),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('also_response', 'related_article', 4),
#     ('also_response', 'article', 'tcm:526-153236')]),
#   (-4.0974803,
#    1.0589474,
#    [('self_loop', 'user', 27924569),
#     ('recommended', 'article', 'tcm:526-10787'),
#     ('recommended', 'user', 224354619),
#     ('recommended', 'article', 'tcm:526-551763')]),
#   (3.6795886,
#    1.0613791,
#    [('self_loop', 'user', 27924569),
#     ('recommended', 'article', 'tcm:526-346380'),
#     ('recommended', 'user', 51718836),
#     ('recommended', 'article', 'tcm:526-784445')]),
#   (-2.6083703,
#    1.0609851,
#    [('self_loop', 'user', 27924569),
#     ('recommended', 'article', 'tcm:526-346380'),
#     ('recommended', 'user', 224133419),
#     ('recommended', 'article', 'tcm:526-209028')])],
#  31705680: [(3.2766569,
#    1.052777,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('also_response', 'related_article', 59),
#     ('also_response', 'article', 'tcm:526-153236')]),
#   (-0.51866883,
#    1.0650553,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 7104236),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (-1.4591277,
#    1.0674292,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-52560'),
#     ('recommended', 'user', 995802261),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (-0.90679854,
#    1.0518311,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('also_response', 'related_article', 40),
#     ('also_response', 'article', 'tcm:526-259315')]),
#   (-4.094323,
#    1.0510696,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-224772'),
#     ('also_response', 'related_article', 38),
#     ('also_response', 'article', 'tcm:526-164352')]),
#   (-0.68871707,
#    1.0600444,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-224772'),
#     ('also_response', 'related_article', 12),
#     ('also_response', 'article', 'tcm:526-191289')]),
#   (-1.8090754,
#    1.0619147,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-224772'),
#     ('recommended', 'user', 224972745),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (1.2283703,
#    1.0709822,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-10849'),
#     ('recommended', 'user', 66637649),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (1.196385,
#    1.0517551,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-209028'),
#     ('also_response', 'related_article', 4),
#     ('also_response', 'article', 'tcm:526-244935')]),
#   (1.2497666,
#    1.0661436,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-70899'),
#     ('recommended', 'user', 249929422),
#     ('recommended', 'article', 'tcm:526-712788')]),
#   (-0.9656879,
#    1.0677394,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 30616906),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (-1.3438915,
#    1.062522,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-551763'),
#     ('recommended', 'user', 22076684),
#     ('recommended', 'article', 'tcm:526-40469')]),
#   (8.408788,
#    1.0650914,
#    [('self_loop', 'user', 31705680),
#     ('recommended', 'article', 'tcm:526-385364'),
#     ('recommended', 'user', 4167342),
#     ('recommended', 'article', 'tcm:526-707527')])],
#  31792890: [(-3.8957245,
#    1.0631827,
#    [('self_loop', 'user', 31792890),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 224684332),
#     ('recommended', 'article', 'tcm:526-199040')]),
#   (-0.36308303,
#    1.0631224,
#    [('self_loop', 'user', 31792890),
#     ('recommended', 'article', 'tcm:526-551763'),
#     ('recommended', 'user', 4684519),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (0.44332847,
#    1.0597398,
#    [('self_loop', 'user', 31792890),
#     ('recommended', 'article', 'tcm:526-191289'),
#     ('recommended', 'user', 15103927),
#     ('recommended', 'article', 'tcm:526-248966')]),
#   (0.9378032,
#    1.0646273,
#    [('self_loop', 'user', 31792890),
#     ('recommended', 'article', 'tcm:526-681575'),
#     ('recommended', 'user', 205962398),
#     ('recommended', 'article', 'tcm:526-704480')]),
#   (3.0835993,
#    1.0471953,
#    [('self_loop', 'user', 31792890),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('also_response', 'related_article', 34),
#     ('also_response', 'article', 'tcm:526-153236')]),
#   (-1.8358237,
#    1.0607307,
#    [('self_loop', 'user', 31792890),
#     ('recommended', 'article', 'tcm:526-239640'),
#     ('recommended', 'user', 1356756),
#     ('recommended', 'article', 'tcm:526-231792')]),
#   (8.603029,
#    1.0624664,
#    [('self_loop', 'user', 31792890),
#     ('recommended', 'article', 'tcm:526-261006'),
#     ('recommended', 'user', 54107074),
#     ('recommended', 'article', 'tcm:526-707527')]),
#   (-0.7409596,
#    1.047769,
#    [('self_loop', 'user', 31792890),
#     ('recommended', 'article', 'tcm:526-40469'),
#     ('also_response', 'related_article', 60),
#     ('also_response', 'article', 'tcm:526-259315')])],
#  17724278: [(-0.8728583,
#    1.0722733,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 995047521),
#     ('recommended', 'article', 'tcm:526-259315')]),
#   (-1.9573908,
#    1.0713108,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 27958094),
#     ('recommended', 'article', 'tcm:526-346380')]),
#   (-4.1021895,
#    1.0727035,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-782343'),
#     ('recommended', 'user', 224427606),
#     ('recommended', 'article', 'tcm:526-164352')]),
#   (-3.865033,
#    1.0567874,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-707527'),
#     ('also_response', 'related_article', 17),
#     ('response_together', 'article', 'tcm:526-199040')]),
#   (-4.068154,
#    1.0651357,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 4144166),
#     ('recommended', 'article', 'tcm:526-46242')]),
#   (1.357868,
#    1.0766128,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('recommended', 'user', 395075),
#     ('recommended', 'article', 'tcm:526-80807')]),
#   (-0.8319008,
#    1.0698534,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-248966'),
#     ('recommended', 'user', 224428456),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (-0.88747984,
#    1.0722717,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 224955718),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (-1.6183451,
#    1.0681183,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-93195'),
#     ('recommended', 'user', 234000057),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (-0.100264035,
#    1.056887,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-248966'),
#     ('also_response', 'related_article', 51),
#     ('recommended_together', 'article', 'tcm:526-656536')]),
#   (0.19294146,
#    1.0720384,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 68136977),
#     ('recommended', 'article', 'tcm:526-249037')]),
#   (-3.969322,
#    1.0612487,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-674187'),
#     ('recommended', 'user', 19678882),
#     ('recommended', 'article', 'tcm:526-551763')]),
#   (-5.15868,
#    1.0645548,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 29345261),
#     ('recommended', 'article', 'tcm:526-70899')]),
#   (-0.5965269,
#    1.0632515,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('recommended', 'user', 2557723),
#     ('recommended', 'article', 'tcm:526-18025')]),
#   (3.23669,
#    1.0668209,
#    [('self_loop', 'user', 17724278),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 24123238),
#     ('recommended', 'article', 'tcm:526-681575')])],
#  224602733: [(3.8572452,
#    1.0615897,
#    [('self_loop', 'user', 224602733),
#     ('recommended', 'article', 'tcm:526-13782'),
#     ('recommended', 'user', 997399556),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (-0.82488644,
#    1.0607685,
#    [('self_loop', 'user', 224602733),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 7568128),
#     ('recommended', 'article', 'tcm:526-209216')]),
#   (-4.1058216,
#    1.0565733,
#    [('self_loop', 'user', 224602733),
#     ('recommended', 'article', 'tcm:526-654768'),
#     ('recommended', 'user', 4631407),
#     ('recommended', 'article', 'tcm:526-551763')]),
#   (-1.5980312,
#    1.0646882,
#    [('self_loop', 'user', 224602733),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('recommended', 'user', 24095001),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (1.3283333,
#    1.0521224,
#    [('self_loop', 'user', 224602733),
#     ('recommended', 'article', 'tcm:526-12167'),
#     ('also_response', 'related_article', 51),
#     ('also_response', 'article', 'tcm:526-12180')]),
#   (2.768075,
#    1.0643468,
#    [('self_loop', 'user', 224602733),
#     ('recommended', 'article', 'tcm:526-707567'),
#     ('recommended', 'user', 224605698),
#     ('recommended', 'article', 'tcm:526-224772')]),
#   (-0.8170573,
#    1.0622106,
#    [('self_loop', 'user', 224602733),
#     ('recommended', 'article', 'tcm:526-492865'),
#     ('recommended', 'user', 997823435),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (3.3558733,
#    1.0480242,
#    [('self_loop', 'user', 224602733),
#     ('recommended', 'article', 'tcm:526-388698'),
#     ('also_response', 'related_article', 37),
#     ('also_response', 'article', 'tcm:526-153236')]),
#   (0.0011192702,
#    1.0579216,
#    [('self_loop', 'user', 224602733),
#     ('recommended', 'article', 'tcm:526-164352'),
#     ('recommended', 'user', 19598537),
#     ('recommended', 'article', 'tcm:526-249037')]),
#   (0.43386784,
#    1.0618242,
#    [('self_loop', 'user', 224602733),
#     ('recommended', 'article', 'tcm:526-261006'),
#     ('recommended', 'user', 992394584),
#     ('recommended', 'article', 'tcm:526-248966')]),
#   (-2.8901544,
#    1.0482068,
#    [('self_loop', 'user', 224602733),
#     ('recommended', 'article', 'tcm:526-237984'),
#     ('also_response', 'related_article', 69),
#     ('also_response', 'article', 'tcm:526-249921')])],
#  37922514: [(-2.3779123,
#    1.0651081,
#    [('self_loop', 'user', 37922514),
#     ('recommended', 'article', 'tcm:526-388698'),
#     ('recommended', 'user', 6167872),
#     ('recommended', 'article', 'tcm:526-209028')]),
#   (2.305755,
#    1.0609396,
#    [('self_loop', 'user', 37922514),
#     ('recommended', 'article', 'tcm:526-191289'),
#     ('recommended', 'user', 264325676),
#     ('recommended', 'article', 'tcm:526-654768')]),
#   (3.3928583,
#    1.0594207,
#    [('self_loop', 'user', 37922514),
#     ('recommended', 'article', 'tcm:526-191289'),
#     ('recommended', 'user', 35990992),
#     ('recommended', 'article', 'tcm:526-784445')]),
#   (-0.9023121,
#    1.063479,
#    [('self_loop', 'user', 37922514),
#     ('recommended', 'article', 'tcm:526-258965'),
#     ('recommended', 'user', 225042425),
#     ('recommended', 'article', 'tcm:526-237984')]),
#   (3.60934,
#    1.0637189,
#    [('self_loop', 'user', 37922514),
#     ('recommended', 'article', 'tcm:526-70899'),
#     ('recommended', 'user', 2587712),
#     ('recommended', 'article', 'tcm:526-204679')]),
#   (-5.269074,
#    1.0659938,
#    [('self_loop', 'user', 37922514),
#     ('recommended', 'article', 'tcm:526-80807'),
#     ('recommended', 'user', 206610458),
#     ('recommended', 'article', 'tcm:526-655038')]),
#   (16.45256,
#    1.0490148,
#    [('self_loop', 'user', 37922514),
#     ('recommended', 'article', 'tcm:526-670542'),
#     ('also_response', 'related_article', 35),
#     ('also_response', 'article', 'tcm:526-10787')]),
#   (0.054675296,
#    1.0635052,
#    [('self_loop', 'user', 37922514),
#     ('recommended', 'article', 'tcm:526-695181'),
#     ('recommended', 'user', 200506324),
#     ('recommended', 'article', 'tcm:526-261006')])],
#  2008451: [(-4.1330757,
#    1.0642906,
#    [('self_loop', 'user', 2008451),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 23546014),
#     ('recommended', 'article', 'tcm:526-551763')]),
#   (-2.767829,
#    1.065256,
#    [('self_loop', 'user', 2008451),
#     ('recommended', 'article', 'tcm:526-209216'),
#     ('recommended', 'user', 225009019),
#     ('recommended', 'article', 'tcm:526-273898')]),
#   (-0.013484152,
#    1.0680236,
#    [('self_loop', 'user', 2008451),
#     ('recommended', 'article', 'tcm:526-655038'),
#     ('recommended', 'user', 8163430),
#     ('recommended', 'article', 'tcm:526-385364')]),
#   (-1.2282254,
#    1.0623094,
#    [('self_loop', 'user', 2008451),
#     ('recommended', 'article', 'tcm:526-18025'),
#     ('recommended', 'user', 68691056),
#     ('recommended', 'article', 'tcm:526-258965')]),
#   (-1.4387656,
#    1.0511358,
#    [('self_loop', 'user', 2008451),
#     ('recommended', 'article', 'tcm:526-191289'),
#     ('also_response', 'related_article', 36),
#     ('also_response', 'article', 'tcm:526-682379')]),
#   (-1.4893277,
#    1.0652062,
#    [('self_loop', 'user', 2008451),
#     ('recommended', 'article', 'tcm:526-52560'),
#     ('recommended', 'user', 24095001),
#     ('recommended', 'article', 'tcm:526-684643')]),
#   (-4.119796,
#    1.0626801,
#    [('self_loop', 'user', 2008451),
#     ('recommended', 'article', 'tcm:526-10787'),
#     ('recommended', 'user', 23546014),
#     ('recommended', 'article', 'tcm:526-164352')]),
#   (-0.6131962,
#    1.0672512,
#    [('self_loop', 'user', 2008451),
#     ('recommended', 'article', 'tcm:526-712788'),
#     ('recommended', 'user', 30117467),
#     ('recommended', 'article', 'tcm:526-688510')]),
#   (-0.10316773,
#    1.0635928,
#    [('self_loop', 'user', 2008451),
#     ('recommended', 'article', 'tcm:526-231792'),
#     ('recommended', 'user', 225367366),
#     ('recommended', 'article', 'tcm:526-682576')]),
#   (0.23007599,
#    1.0681264,
#    [('self_loop', 'user', 2008451),
#     ('recommended', 'article', 'tcm:526-10838'),
#     ('recommended', 'user', 53421807),
#     ('recommended', 'article', 'tcm:526-249037')]),
#   (-3.8689284,
#    1.0660737,
#    [('self_loop', 'user', 2008451),
#     ('recommended', 'article', 'tcm:526-10787'),
#     ('recommended', 'user', 142942),
#     ('recommended', 'article', 'tcm:526-199040')])]}
